# %% [markdown]
# # MINIST画像認識
#
# **画像認識**
#
# **KaggleのMINSTを活用**
#
# **CNNを活用して画像認識を実施する**
#
# **ライブラリは、Numpyを活用**

# %%
import sys, os
sys.path.append(os.pardir)
import pickle
import numpy as np
from collections import OrderedDict
from common import layers
from common import optimizer
from data.mnist import load_mnist
import matplotlib.pyplot as plt

# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(flatten=False)

print("データ読み込み完了")

# 処理に時間のかかる場合はデータを削減 
x_train, d_train = x_train[:5000], d_train[:5000]
x_test, d_test = x_test[:1000], d_test[:1000]
#CNN(double)を設定(layers.pyにクラス定義されている)
network = layers.DoubleConvNet(input_dim=(1,28,28), 
                          conv_param_1={'filter_num':10, 'filter_size':7, 'pad':1, 'stride':1},
                          conv_param_2={'filter_num':20, 'filter_size':3, 'pad':1, 'stride':1},
                          hidden_size=100, output_size=10, weight_init_std=0.01)
# 必要なライブラリのインポート、最適化手法はAdamを使う
optimizer = optimizer.Adam()
# 重み初期値
iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
# パラメータの初期化
train_loss_list = []
accuracies_train = []
accuracies_test = []
# 描写頻度
plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]
    
    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    
    # 学習結果を表示
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               

#グラフを作成
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.164
#                 : 10. 正答率(テスト) = 0.138
# Generation: 20. 正答率(トレーニング) = 0.3724
#                 : 20. 正答率(テスト) = 0.348
# Generation: 30. 正答率(トレーニング) = 0.6102
#                 : 30. 正答率(テスト) = 0.605
# Generation: 40. 正答率(トレーニング) = 0.7278
#                 : 40. 正答率(テスト) = 0.69
# Generation: 50. 正答率(トレーニング) = 0.762
#                 : 50. 正答率(テスト) = 0.725
# Generation: 60. 正答率(トレーニング) = 0.8432
#                 : 60. 正答率(テスト) = 0.811
# Generation: 70. 正答率(トレーニング) = 0.845
#                 : 70. 正答率(テスト) = 0.802
# Generation: 80. 正答率(トレーニング) = 0.858
#                 : 80. 正答率(テスト) = 0.826
# Generation: 90. 正答率(トレーニング) = 0.86
#                 : 90. 正答率(テスト) = 0.811
# Generation: 100. 正答率(トレーニング) = 0.8818
#                 : 100. 正答率(テスト) = 0.859
# Generation: 110. 正答率(トレーニング) = 0.8818
#                 : 110. 正答率(テスト) = 0.855
# Generation: 120. 正答率(トレーニング) = 0.8916
#                 : 120. 正答率(テスト) = 0.866
# Generation: 130. 正答率(トレーニング) = 0.897
#                 : 130. 正答率(テスト) = 0.872
# Generation: 140. 正答率(トレーニング) = 0.912
#                 : 140. 正答率(テスト) = 0.881
# Generation: 150. 正答率(トレーニング) = 0.906
#                 : 150. 正答率(テスト) = 0.887
# Generation: 160. 正答率(トレーニング) = 0.9112
#                 : 160. 正答率(テスト) = 0.893
# Generation: 170. 正答率(トレーニング) = 0.9068
#                 : 170. 正答率(テスト) = 0.881
# Generation: 180. 正答率(トレーニング) = 0.925
#                 : 180. 正答率(テスト) = 0.885
# Generation: 190. 正答率(トレーニング) = 0.9244
#                 : 190. 正答率(テスト) = 0.899
# Generation: 200. 正答率(トレーニング) = 0.9182
#                 : 200. 正答率(テスト) = 0.894
# Generation: 210. 正答率(トレーニング) = 0.923
#                 : 210. 正答率(テスト) = 0.898
# Generation: 220. 正答率(トレーニング) = 0.922
#                 : 220. 正答率(テスト) = 0.894
# Generation: 230. 正答率(トレーニング) = 0.9288
#                 : 230. 正答率(テスト) = 0.887
# Generation: 240. 正答率(トレーニング) = 0.9344
#                 : 240. 正答率(テスト) = 0.909
# Generation: 250. 正答率(トレーニング) = 0.94
#                 : 250. 正答率(テスト) = 0.913
# Generation: 260. 正答率(トレーニング) = 0.9262
#                 : 260. 正答率(テスト) = 0.893
# Generation: 270. 正答率(トレーニング) = 0.9408
#                 : 270. 正答率(テスト) = 0.908
# Generation: 280. 正答率(トレーニング) = 0.9438
#                 : 280. 正答率(テスト) = 0.918
# Generation: 290. 正答率(トレーニング) = 0.9464
#                 : 290. 正答率(テスト) = 0.917
# Generation: 300. 正答率(トレーニング) = 0.951
#                 : 300. 正答率(テスト) = 0.921
# Generation: 310. 正答率(トレーニング) = 0.948
#                 : 310. 正答率(テスト) = 0.916
# Generation: 320. 正答率(トレーニング) = 0.9438
#                 : 320. 正答率(テスト) = 0.922
# Generation: 330. 正答率(トレーニング) = 0.957
#                 : 330. 正答率(テスト) = 0.93
# Generation: 340. 正答率(トレーニング) = 0.9436
#                 : 340. 正答率(テスト) = 0.9
# Generation: 350. 正答率(トレーニング) = 0.9516
#                 : 350. 正答率(テスト) = 0.923
# Generation: 360. 正答率(トレーニング) = 0.9562
#                 : 360. 正答率(テスト) = 0.922
# Generation: 370. 正答率(トレーニング) = 0.9614
#                 : 370. 正答率(テスト) = 0.93
# Generation: 380. 正答率(トレーニング) = 0.9636
#                 : 380. 正答率(テスト) = 0.941
# Generation: 390. 正答率(トレーニング) = 0.957
#                 : 390. 正答率(テスト) = 0.934
# Generation: 400. 正答率(トレーニング) = 0.9596
#                 : 400. 正答率(テスト) = 0.936
# Generation: 410. 正答率(トレーニング) = 0.9592
#                 : 410. 正答率(テスト) = 0.936
# Generation: 420. 正答率(トレーニング) = 0.9606
#                 : 420. 正答率(テスト) = 0.933
# Generation: 430. 正答率(トレーニング) = 0.9616
#                 : 430. 正答率(テスト) = 0.927
# Generation: 440. 正答率(トレーニング) = 0.9668
#                 : 440. 正答率(テスト) = 0.946
# Generation: 450. 正答率(トレーニング) = 0.9658
#                 : 450. 正答率(テスト) = 0.923
# Generation: 460. 正答率(トレーニング) = 0.964
#                 : 460. 正答率(テスト) = 0.943
# Generation: 470. 正答率(トレーニング) = 0.9672
#                 : 470. 正答率(テスト) = 0.944
# Generation: 480. 正答率(トレーニング) = 0.9678
#                 : 480. 正答率(テスト) = 0.939
# Generation: 490. 正答率(トレーニング) = 0.9678
#                 : 490. 正答率(テスト) = 0.942
# Generation: 500. 正答率(トレーニング) = 0.9722
#                 : 500. 正答率(テスト) = 0.942
# Generation: 510. 正答率(トレーニング) = 0.9686
#                 : 510. 正答率(テスト) = 0.937
# Generation: 520. 正答率(トレーニング) = 0.9712
#                 : 520. 正答率(テスト) = 0.943
# Generation: 530. 正答率(トレーニング) = 0.9734
#                 : 530. 正答率(テスト) = 0.944
# Generation: 540. 正答率(トレーニング) = 0.9792
#                 : 540. 正答率(テスト) = 0.948
# Generation: 550. 正答率(トレーニング) = 0.979
#                 : 550. 正答率(テスト) = 0.95
# Generation: 560. 正答率(トレーニング) = 0.9766
#                 : 560. 正答率(テスト) = 0.95
# Generation: 570. 正答率(トレーニング) = 0.979
#                 : 570. 正答率(テスト) = 0.946
# Generation: 580. 正答率(トレーニング) = 0.9776
#                 : 580. 正答率(テスト) = 0.945
# Generation: 590. 正答率(トレーニング) = 0.9784
#                 : 590. 正答率(テスト) = 0.943
# Generation: 600. 正答率(トレーニング) = 0.9786
#                 : 600. 正答率(テスト) = 0.947
# Generation: 610. 正答率(トレーニング) = 0.9788
#                 : 610. 正答率(テスト) = 0.948
# Generation: 620. 正答率(トレーニング) = 0.9822
#                 : 620. 正答率(テスト) = 0.952
# Generation: 630. 正答率(トレーニング) = 0.9814
#                 : 630. 正答率(テスト) = 0.951
# Generation: 640. 正答率(トレーニング) = 0.9862
#                 : 640. 正答率(テスト) = 0.952
# Generation: 650. 正答率(トレーニング) = 0.979
#                 : 650. 正答率(テスト) = 0.945
# Generation: 660. 正答率(トレーニング) = 0.9836
#                 : 660. 正答率(テスト) = 0.953
# Generation: 670. 正答率(トレーニング) = 0.9832
#                 : 670. 正答率(テスト) = 0.95
# Generation: 680. 正答率(トレーニング) = 0.9868
#                 : 680. 正答率(テスト) = 0.954
# Generation: 690. 正答率(トレーニング) = 0.987
#                 : 690. 正答率(テスト) = 0.95
# Generation: 700. 正答率(トレーニング) = 0.9886
#                 : 700. 正答率(テスト) = 0.948
# Generation: 710. 正答率(トレーニング) = 0.9888
#                 : 710. 正答率(テスト) = 0.954
# Generation: 720. 正答率(トレーニング) = 0.9844
#                 : 720. 正答率(テスト) = 0.948
# Generation: 730. 正答率(トレーニング) = 0.986
#                 : 730. 正答率(テスト) = 0.954
# Generation: 740. 正答率(トレーニング) = 0.9902
#                 : 740. 正答率(テスト) = 0.958
# Generation: 750. 正答率(トレーニング) = 0.9814
#                 : 750. 正答率(テスト) = 0.951
# Generation: 760. 正答率(トレーニング) = 0.9848
#                 : 760. 正答率(テスト) = 0.953
# Generation: 770. 正答率(トレーニング) = 0.9868
#                 : 770. 正答率(テスト) = 0.96
# Generation: 780. 正答率(トレーニング) = 0.9844
#                 : 780. 正答率(テスト) = 0.945
# Generation: 790. 正答率(トレーニング) = 0.9852
#                 : 790. 正答率(テスト) = 0.957
# Generation: 800. 正答率(トレーニング) = 0.9868
#                 : 800. 正答率(テスト) = 0.958
# Generation: 810. 正答率(トレーニング) = 0.9882
#                 : 810. 正答率(テスト) = 0.962
# Generation: 820. 正答率(トレーニング) = 0.989
#                 : 820. 正答率(テスト) = 0.957
# Generation: 830. 正答率(トレーニング) = 0.9908
#                 : 830. 正答率(テスト) = 0.96
# Generation: 840. 正答率(トレーニング) = 0.9874
#                 : 840. 正答率(テスト) = 0.96
# Generation: 850. 正答率(トレーニング) = 0.9894
#                 : 850. 正答率(テスト) = 0.957
# Generation: 860. 正答率(トレーニング) = 0.9872
#                 : 860. 正答率(テスト) = 0.953
# Generation: 870. 正答率(トレーニング) = 0.9852
#                 : 870. 正答率(テスト) = 0.957
# Generation: 880. 正答率(トレーニング) = 0.9878
#                 : 880. 正答率(テスト) = 0.953
# Generation: 890. 正答率(トレーニング) = 0.9918
#                 : 890. 正答率(テスト) = 0.963
# Generation: 900. 正答率(トレーニング) = 0.9908
#                 : 900. 正答率(テスト) = 0.958
# Generation: 910. 正答率(トレーニング) = 0.9944
#                 : 910. 正答率(テスト) = 0.967
# Generation: 920. 正答率(トレーニング) = 0.9938
#                 : 920. 正答率(テスト) = 0.961
# Generation: 930. 正答率(トレーニング) = 0.9956
#                 : 930. 正答率(テスト) = 0.962
# Generation: 940. 正答率(トレーニング) = 0.9924
#                 : 940. 正答率(テスト) = 0.957
# Generation: 950. 正答率(トレーニング) = 0.9942
#                 : 950. 正答率(テスト) = 0.963
# Generation: 960. 正答率(トレーニング) = 0.9954
#                 : 960. 正答率(テスト) = 0.96
# Generation: 970. 正答率(トレーニング) = 0.995
#                 : 970. 正答率(テスト) = 0.958
# Generation: 980. 正答率(トレーニング) = 0.995
#                 : 980. 正答率(テスト) = 0.959
# Generation: 990. 正答率(トレーニング) = 0.9944
#                 : 990. 正答率(テスト) = 0.959
# Generation: 1000. 正答率(トレーニング) = 0.9944
#                 : 1000. 正答率(テスト) = 0.955
